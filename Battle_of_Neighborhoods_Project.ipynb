# %% [markdown]
# <h1 style='text-align: center'>Battle of Neighborhoods in London</h1>

# %% [markdown]
# <h3>1. Inroduction</h3>

# %% [markdown]
# In this project, we’ll try to solve a problem which happens to people who are visiting a new city
# which is for example, what are the good affordable restaurants in a given neighborhood/town that serve good and affordable
# cuisines of ones liking? So, the scope of this project will be to provide a list of good restaurants which provide
# the cuisine of their choice also it should be affordable and should have good reviews as well.
#
# Since London is one of the many multicultural cities around the world, we will be comparing the
# neighborhoods of London and cumulating a list of restaurants based on the cuisine they serve,
# their affordability and ratings.
# For this to work we’ll rely on data collected from different sources and various types of
# visualizations including plotting the areas on the map.

# %% [markdown]
# <h3>2. Gathering required data</h3>

# %% [markdown]
# For this project we’ll be gathering public data from following sources:
# 1. Wikipedia (https://en.wikipedia.org/wiki/List_of_areas_of_London): Here we can get the data
# regarding boroughs and the areas within those boroughs. Since this data is based on the areas
# under the boroughs, but using grouping we can group these areas based on the boroughs they
# belong to.
#
#
# 2. Foursquare: Using Foursquare API we can obtain longitudes and latitudes of all the boroughs and
# using that data we can plot the locations and popular venues in London. Also using this API, we
# can also get the details of all the restaurants that serve different types of cuisines from around
# the world.

# %% [markdown]
# #### Importing necessary libraries

# %%
# Data imports
import pandas as pd
import numpy as np

# Visualization imports
import matplotlib.pyplot as plt
import seaborn as sns

# Webpage scraping imports
import urllib.request
from bs4 import BeautifulSoup
import requests

# Imports to transform from JSON data to Pandas DataFrame
from pandas.io.json import json_normalize

# Import for reading a JSON file 
import json

# Import for getting location coordinates
import geocoder

# Import for creating and plotting the data on a map
import folium

# Import for getting the coordinates of the given location
from geopy.geocoders import Nominatim

# %% [markdown]
# #### Scraping web data from wikipedia

# %%
#URL for wikipedia data
url='https://en.wikipedia.org/wiki/List_of_areas_of_London'

# opening the URL using urllib.request.uropen() method into the page variable
page = urllib.request.urlopen(url)

# parsing the HTML from our URL into the BeautifulSoup parse tree format
soup = BeautifulSoup(page,'lxml')
soup.prettify()

# using 'find_all' function, we can bring back all instances of the 'table' especially,
# under tbody tag in the HTML and store it in a variable
ldn_table = soup.find('table',class_ = 'wikitable sortable').tbody

#creating an area list for our data from table in wikipedia page
area_list = [[],[],[],[],[],[]]

# appending the data from wikipedia into out area list 
for row in ldn_table.findAll('tr'):
    cells=row.findAll('td')
    if len(cells)==6:
        for i in range(6):
            area_list[i].append(cells[i].find(text=True).strip())

# creating a list for column names
column_names = ['Location','Boroughs','Post Town','Postcode','Dial Code','OS grid ref']

# creating a DataFrame from our list
london_df = pd.DataFrame(columns=column_names)
for i in range(len(column_names)):
    london_df[column_names[i]] = area_list[i]
london_df
# Out:
#             Location                        Boroughs       Post Town  \
# 0         Abbey Wood              Bexley,  Greenwich          LONDON
# 1              Acton  Ealing, Hammersmith and Fulham          LONDON
# 2          Addington                         Croydon         CROYDON
# 3         Addiscombe                         Croydon         CROYDON
# 4        Albany Park                          Bexley  BEXLEY, SIDCUP
# ..               ...                             ...             ...
# 528         Woolwich                       Greenwich          LONDON
# 529   Worcester Park    Sutton, Kingston upon Thames  WORCESTER PARK
# 530  Wormwood Scrubs          Hammersmith and Fulham          LONDON
# 531          Yeading                      Hillingdon           HAYES
# 532         Yiewsley                      Hillingdon    WEST DRAYTON
#
#       Postcode Dial Code OS grid ref
# 0          SE2       020    TQ465785
# 1       W3, W4       020    TQ205805
# 2          CR0       020    TQ375645
# 3          CR0       020    TQ345665
# 4    DA5, DA14       020    TQ478728
# ..         ...       ...         ...
# 528       SE18       020    TQ435795
# 529        KT4       020    TQ225655
# 530        W12       020    TQ225815
# 531        UB4       020    TQ115825
# 532        UB7       020    TQ063804
#
# [533 rows x 6 columns]

# %% [markdown]
# Since we won't be using Dial Code and OS grid ref columns in this project, we'll drop those columns

# %%
london_df.drop(['Dial Code','OS grid ref'],axis=1,inplace=True)
london_df
# Out:
#             Location                        Boroughs       Post Town  \
# 0         Abbey Wood              Bexley,  Greenwich          LONDON
# 1              Acton  Ealing, Hammersmith and Fulham          LONDON
# 2          Addington                         Croydon         CROYDON
# 3         Addiscombe                         Croydon         CROYDON
# 4        Albany Park                          Bexley  BEXLEY, SIDCUP
# ..               ...                             ...             ...
# 528         Woolwich                       Greenwich          LONDON
# 529   Worcester Park    Sutton, Kingston upon Thames  WORCESTER PARK
# 530  Wormwood Scrubs          Hammersmith and Fulham          LONDON
# 531          Yeading                      Hillingdon           HAYES
# 532         Yiewsley                      Hillingdon    WEST DRAYTON
#
#       Postcode
# 0          SE2
# 1       W3, W4
# 2          CR0
# 3          CR0
# 4    DA5, DA14
# ..         ...
# 528       SE18
# 529        KT4
# 530        W12
# 531        UB4
# 532        UB7
#
# [533 rows x 4 columns]

# %% [markdown]
# Removing all the locations from the DataFrame which don't have London as its Post Town

# %%
london_df = london_df[london_df['Post Town']=='LONDON']
london_df
# Out:
#             Location                        Boroughs Post Town  Postcode
# 0         Abbey Wood              Bexley,  Greenwich    LONDON       SE2
# 1              Acton  Ealing, Hammersmith and Fulham    LONDON    W3, W4
# 6            Aldgate                            City    LONDON       EC3
# 7            Aldwych                     Westminster    LONDON       WC2
# 9            Anerley                         Bromley    LONDON      SE20
# ..               ...                             ...       ...       ...
# 522       Wood Green                        Haringey    LONDON       N22
# 523         Woodford                       Redbridge    LONDON  IG8, E18
# 527    Woodside Park                          Barnet    LONDON       N12
# 528         Woolwich                       Greenwich    LONDON      SE18
# 530  Wormwood Scrubs          Hammersmith and Fulham    LONDON       W12
#
# [299 rows x 4 columns]

# %% [markdown]
# Getting the a count for number of locations under each borough

# %%
london_df['Boroughs'].value_counts()
# Out:
# Barnet                                      25
# Tower Hamlets                               21
# Westminster                                 19
# Hackney                                     18
# Lewisham                                    17
# Camden                                      17
# Haringey                                    15
# Islington                                   14
# Newham                                      13
# Southwark                                   13
# Greenwich                                   13
# Brent                                       11
# Lambeth                                     10
# Wandsworth                                  10
# Kensington and Chelsea                       9
# Hammersmith and Fulham                       9
# Waltham Forest                               8
# Enfield                                      6
# Merton                                       5
# Bromley                                      4
# Richmond upon Thames                         4
# Croydon                                      4
# Ealing                                       4
# City                                         3
# Redbridge                                    3
# Bexley                                       2
# Hounslow                                     2
# Bexley,  Greenwich                           1
# City, Westminster                            1
# Lewisham, Southwark                          1
# Kingston upon Thames                         1
# Brent, Camden                                1
# Haringey, Islington                          1
# Ealing, Hammersmith and Fulham               1
# Haringey and Barnet                          1
# Barnet, Brent, Camden                        1
# Dartford                                     1
# Redbridge, Waltham Forest                    1
# Lewisham, Bromley                            1
# Camden and Islington                         1
# Islington, Camden                            1
# Greenwich, Lewisham                          1
# Islington & City                             1
# Lambeth, Wandsworth                          1
# Lambeth, Southwark                           1
# Hounslow, Ealing, Hammersmith and Fulham     1
# Brent, Ealing                                1
# Name: Boroughs, dtype: int64

# %% [markdown]
# The result above shows us that Boroughs like Barnet, Tower Hamlets, Westminster and Hackney etc have higher number of locations than others.
#
# For our project we'll be choosing locations of Westminster and Camden which is a borough in London.

# %%
#creating a new dataframe for the locations of Westminster.
westminster_df = london_df[london_df['Boroughs']=='Westminster']
westminster_df
# Out:
#            Location     Boroughs Post Town Postcode
# 7           Aldwych  Westminster    LONDON      WC2
# 28        Bayswater  Westminster    LONDON       W2
# 35        Belgravia  Westminster    LONDON      SW1
# 87    Charing Cross  Westminster    LONDON      WC2
# 95        Chinatown  Westminster    LONDON       W1
# 114   Covent Garden  Westminster    LONDON      WC2
# 273   Knightsbridge  Westminster    LONDON      SW1
# 287    Lisson Grove  Westminster    LONDON      NW8
# 289   Little Venice  Westminster    LONDON   W9, W2
# 296      Maida Vale  Westminster    LONDON       W9
# 302      Marylebone  Westminster    LONDON       W1
# 303         Mayfair  Westminster    LONDON       W1
# 309        Millbank  Westminster    LONDON      SW1
# 356      Paddington  Westminster    LONDON       W2
# 366         Pimlico  Westminster    LONDON      SW1
# 410            Soho  Westminster    LONDON       W1
# 429      St James's  Westminster    LONDON      SW1
# 433  St John's Wood  Westminster    LONDON      NW8
# 513     Westminster  Westminster    LONDON      SW1

# %% [markdown]
# Creating a function that returns coordinates for the given location.

# %%
def get_coordinates(postalCode):
    coords = None
    while(coords is None):
        g = geocoder.arcgis('{}, London, United Kingdom'.format(postalCode))
        coords = g.latlng
    return coords

#creating a list for getting all the coordinates
postalCodes,coordinates = westminster_df['Postcode'].tolist(),[[],[]]

for postcode in postalCodes:
    coor = get_coordinates(postcode)
    coordinates[0].append(coor[0])
    coordinates[1].append(coor[1])

# %% [markdown]
# Adding the coordinate data to out dataframe

# %%
westminster_df['Latitude'] = coordinates[0]
westminster_df['Longitude'] = coordinates[1]
westminster_df
# Out:
# <ipython-input-8-066133991f9b>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   westminster_df['Latitude'] = coordinates[0]
# <ipython-input-8-066133991f9b>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   westminster_df['Longitude'] = coordinates[1]
#            Location     Boroughs Post Town Postcode  Latitude  Longitude
# 7           Aldwych  Westminster    LONDON      WC2  51.51651   -0.11968
# 28        Bayswater  Westminster    LONDON       W2  51.51494   -0.18048
# 35        Belgravia  Westminster    LONDON      SW1  51.49714   -0.13829
# 87    Charing Cross  Westminster    LONDON      WC2  51.51651   -0.11968
# 95        Chinatown  Westminster    LONDON       W1  51.51656   -0.14770
# 114   Covent Garden  Westminster    LONDON      WC2  51.51651   -0.11968
# 273   Knightsbridge  Westminster    LONDON      SW1  51.49714   -0.13829
# 287    Lisson Grove  Westminster    LONDON      NW8  51.53398   -0.17378
# 289   Little Venice  Westminster    LONDON   W9, W2  51.52587   -0.19526
# 296      Maida Vale  Westminster    LONDON       W9  51.52587   -0.19526
# 302      Marylebone  Westminster    LONDON       W1  51.51656   -0.14770
# 303         Mayfair  Westminster    LONDON       W1  51.51656   -0.14770
# 309        Millbank  Westminster    LONDON      SW1  51.49714   -0.13829
# 356      Paddington  Westminster    LONDON       W2  51.51494   -0.18048
# 366         Pimlico  Westminster    LONDON      SW1  51.49714   -0.13829
# 410            Soho  Westminster    LONDON       W1  51.51656   -0.14770
# 429      St James's  Westminster    LONDON      SW1  51.49714   -0.13829
# 433  St John's Wood  Westminster    LONDON      NW8  51.53398   -0.17378
# 513     Westminster  Westminster    LONDON      SW1  51.49714   -0.13829

# %%
#creating a new dataframe for the locations of Camden.
camden_df = london_df[london_df['Boroughs']=='Camden']
camden_df
# Out:
#            Location Boroughs Post Town       Postcode
# 39     Belsize Park   Camden    LONDON            NW3
# 54       Bloomsbury   Camden    LONDON            WC1
# 76      Camden Town   Camden    LONDON            NW1
# 86       Chalk Farm   Camden    LONDON            NW1
# 174       Fitzrovia   Camden    LONDON             W1
# 182         Frognal   Camden    LONDON            NW3
# 192      Gospel Oak   Camden    LONDON       NW5, NW3
# 210       Hampstead   Camden    LONDON            NW3
# 239        Highgate   Camden    LONDON             N6
# 242         Holborn   Camden    LONDON       WC1, WC2
# 263    Kentish Town   Camden    LONDON            NW5
# 375   Primrose Hill   Camden    LONDON  NW1, NW3, NW8
# 411      Somerstown   Camden    LONDON            NW1
# 431        St Giles   Camden    LONDON            WC2
# 436      St Pancras   Camden    LONDON            WC1
# 453   Swiss Cottage   Camden    LONDON            NW3
# 505  West Hampstead   Camden    LONDON            NW6

# %% [markdown]
# Getting the coordinates for the locations in Camden using get_coordinates funtion

# %%
postalCodes,coordinates = camden_df['Postcode'].tolist(),[[],[]]

for postcode in postalCodes:
    coor = get_coordinates(postcode)
    coordinates[0].append(coor[0])
    coordinates[1].append(coor[1])
    
camden_df['Latitude'] = coordinates[0]
camden_df['Longitude'] = coordinates[1]
camden_df
# Out:
# <ipython-input-10-2f1e1565a728>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   camden_df['Latitude'] = coordinates[0]
# <ipython-input-10-2f1e1565a728>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   camden_df['Longitude'] = coordinates[1]
#            Location Boroughs Post Town       Postcode  Latitude  Longitude
# 39     Belsize Park   Camden    LONDON            NW3  51.55506   -0.17348
# 54       Bloomsbury   Camden    LONDON            WC1  51.52450   -0.12273
# 76      Camden Town   Camden    LONDON            NW1  51.53354   -0.14606
# 86       Chalk Farm   Camden    LONDON            NW1  51.53354   -0.14606
# 174       Fitzrovia   Camden    LONDON             W1  51.51656   -0.14770
# 182         Frognal   Camden    LONDON            NW3  51.55506   -0.17348
# 192      Gospel Oak   Camden    LONDON       NW5, NW3  51.55506   -0.17348
# 210       Hampstead   Camden    LONDON            NW3  51.55506   -0.17348
# 239        Highgate   Camden    LONDON             N6  51.57145   -0.14983
# 242         Holborn   Camden    LONDON       WC1, WC2  51.52450   -0.12273
# 263    Kentish Town   Camden    LONDON            NW5  51.55570   -0.13926
# 375   Primrose Hill   Camden    LONDON  NW1, NW3, NW8  51.53398   -0.17378
# 411      Somerstown   Camden    LONDON            NW1  51.53354   -0.14606
# 431        St Giles   Camden    LONDON            WC2  51.51651   -0.11968
# 436      St Pancras   Camden    LONDON            WC1  51.52450   -0.12273
# 453   Swiss Cottage   Camden    LONDON            NW3  51.55506   -0.17348
# 505  West Hampstead   Camden    LONDON            NW6  51.54187   -0.19795

# %% [markdown]
# <h3>3. Exploring the data</h3>

# %% [markdown]
# Let's first plot the areas on a map

# %%
# Assigning the address to a variable
address = 'City of Westminster, London, UK'

# Getting the corrdinates of Westminster using address
geolocator = Nominatim(user_agent="westminster_map")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude

# Creating a map of Westmister
westmister_map = folium.Map(location=[latitude, longitude], zoom_start=10)

# Plotting all the locations on the map
for lat, lng, borough, neighborhood in zip(westminster_df['Latitude'], westminster_df['Longitude'], westminster_df['Boroughs'], westminster_df['Location']):
    label = '{}, {}'.format(neighborhood, borough)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(westmister_map)  
    
westmister_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
#Getting foursquare credentials from a JSON file
f=open('credentials.json',)
cred = json.load(f)
f.close()
VERSION = '20180605' # Foursquare API version

# %% [markdown]
# #### Getting the top 100 venues in Westminster

# %%
# creating the URL for the request first
limit = 500 # limit for the number of venues returned by Foursquare API
radius=500 # define radius

url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
    cred['CLIENT_ID'], 
    cred['CLIENT_SECRET'], 
    VERSION, 
    latitude, 
    longitude, 
    radius, 
    limit)

#getting the results from the API
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5eb6d135b9a389001c926459'},
#  'response': {'suggestedFilters': {'header': 'Tap to show:',
#    'filters': [{'name': 'Open now', 'key': 'openNow'}]},
#   'headerLocation': 'City of Westminster',
#   'headerFullLocation': 'City of Westminster, London',
#   'headerLocationGranularity': 'neighborhood',
#   'totalResults': 75,
#   'suggestedBounds': {'ne': {'lat': 51.501820604500004,
#     'lng': -0.1299341681427764},
#    'sw': {'lat': 51.4928205955, 'lng': -0.1443638318572236}},
#   'groups': [{'type': 'Recommended Places',
#     'name': 'recommended',
#     'items': [{'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '53645bf211d2576d6ff59feb',
#        'name': 'Curzon Victoria',
#        'location': {'address': '58 Victoria St',
#         'lat': 51.497472657293244,
#         'lng': -0.13674352372372592,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 51.497472657293244,
#           'lng': -0.13674352372372592}],
#         'distance': 32,
#         'postalCode': 'SW1E 6QW',
#         'cc': 'GB',
#         'city': 'London',
#         'state': 'Greater London',
#         'country': 'United Kingdom',
#         'formattedAddress': ['58 Victoria St',
#          'London',
#          'Greater London',
#          'SW1E 6QW',
#          'United Kingdom']},
#        'categories': [{'id': '4bf58dd8d48988d17f941735',
#          'name': 'Movie Theater',
#          'pluralName': 'Movie Theaters',
#          'shortName': 'Movie Theater',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/movietheater_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-53645bf211d2576d6ff59feb-0'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b648050f964a52095b82ae3',
#        'name': 'Run & Become',
#        'location': {'address': '4a Eccleston St',
#         'lat': 51.49812818794526,
#         'lng': -0.13542610570509078,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 51.49812818794526,
#           'lng': -0.13542610570509078}],
#         'distance': 149,
#         'postalCode': 'SW1W 9LN',
#         'cc': 'GB',
#         'city': 'London',
#         'state': 'Greater London',
#         'country': 'United Kingdom',
#         'formattedAddress': ['4a Eccleston St',
#          'London',
#          'Greater London',
#          'SW1W 9LN',
#          'United Kingdom']},
#        'categories': [{'id': '4bf58dd8d48988d1f2941735',
#          'name': 'Sporting Goods Shop',
#          'pluralName': 'Sporting Goods Shops',
#          'shortName': 'Sporting Goods',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/sports_outdoors_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b648050f964a52095b82ae3-1'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '534295ec498e271e54f5f569',
#        'name': 'Iris & June',
#        'location': {'address': '1 Howick Pl',
#         'lat': 51.496791,
#         'lng': -0.136011,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 51.496791,
#           'lng': -0.136011}],
#         'distance': 98,
#         'postalCode': 'SW1P 1WG',
#         'cc': 'GB',
#         'neighborhood': 'City of Westminster',
#         'city': 'London',
#         'state': 'Greater London',
#         'country': 'United Kingdom',
#         'formattedAddress': ['1 Howick Pl',
#          'London',
#          'Greater London',
#          'SW1P 1WG',
#          'United Kingdom']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-534295ec498e271e54f5f569-2'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4f64ea20e4b0c7552d443a6c',
#        'name': 'Taj  51 Buckingham Gate Suites & Residences',
#        'location': {'address': '51 Buckingham Gate',
#         'lat': 51.49859750553769,
#         'lng': -0.1374039555861322,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 51.49859750553769,
#           'lng': -0.1374039555861322}],
#         'distance': 143,
#         'postalCode': 'SW1E 6AF',
#         'cc': 'GB',
#         'city': 'London',
#         'state': 'Greater London',
#         'country': 'United Kingdom',
#         'formattedAddress': ['51 Buckingham Gate',
#          'London',
#          'Greater London',
#          'SW1E 6AF',
#          'United Kingdom']},
#        'categories': [{'id': '4bf58dd8d48988d1fa931735',
#          'name': 'Hotel',
#          'pluralName': 'Hotels',
#          'shortName': 'Hotel',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4f64ea20e4b0c7552d443a6c-3'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5c67f97335d3fc002c79193b',
#        'name': 'Chez Antoinette',
#        'location': {'address': '22 Palmer St',
#         'crossStreet': 'The Caxton',
#         'lat': 51.497964,
#         'lng': -0.135455,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 51.497964,
#           'lng': -0.135455}],
#         'distance': 137,
#         'postalCode': 'SW1H 0PH',
#         'cc': 'GB',
#         'city': 'Victoria',
#         'state': 'Greater London',
#         'country': 'United Kingdom',
#         'formattedAddress': ['22 Palmer St (The Caxton)',
#          'Victoria',
#          'Greater London',
#          'SW1H 0PH',
#          'United Kingdom']},
#        'categories': [{'id': '4bf58dd8d48988d10c941735',
#          'name': 'French Restaurant',
#          'pluralName': 'French Restaurants',
#          'shortName': 'French',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/french_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '537454416'}},
#       'referralId': 'e-0-5c67f97335d3fc002c79193b-4'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5ca89476625a66002cb1dd0c',
#        'name': 'Formative',
#        'location': {'address': '4 Butler Pl',
#         'lat': 51.498311,
#         'lng': -0.134917,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 51.498311,
#           'lng': -0.134917}],
#         'distance': 189,
#         'postalCode': 'SW1H 0RH',
#         'cc': 'GB',
#         'city': 'London',
#         'state': 'Greater London',
#         'country': 'United Kingdom',
#         'formattedAddress': ['4 Butler Pl',
#          'London',
#          'Greater London',
#          'SW1H 0RH',
#          'United Kingdom']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5ca89476625a66002cb1dd0c-5'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4ac518ddf964a5208aa920e3',
#        'name': 'Quilon',
#        'location': {'address': '41 Buckingham Gate',
#         'lat': 51.49877248841534,
#         'lng': -0.13752218091498283,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 51.49877248841534,
#           'lng': -0.13752218091498283}],
#         'distance': 163,
#         'postalCode': 'SW1E 6AF',
#         'cc': 'GB',
#         'city': 'London',
#         'state': 'Greater London',
#         'country': 'United Kingdom',
#         'formattedAddress': ['41 Buckingham Gate',
#          'London',
#          'Greater London',
#          'SW1E 6AF',
#          'United Kingdom']},
#        'categories': [{'id': '4bf58dd8d48988d10f941735',
#          'name': 'Indian Restaurant',
#          'pluralName': 'Indian Restaurants',
#          'shortName': 'Indian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4ac518ddf964a5208aa920e3-6'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b0c6aa1f964a520cd3c23e3',
#        'name': 'Flat Cap Coffee Co',
#        'location': {'address': '4 Strutton Ground',
#         'crossStreet': 'at Old Pye St',
#         'lat': 51.49749647419568,
#         'lng': -0.13385812172317216,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 51.49749647419568,
#           'lng': -0.13385812172317216}],
#         'distance': 228,
#         'postalCode': 'SW1P 2HR',
#         'cc': 'GB',
#         'city': 'London',
#         'state': 'Greater London',
#         'country': 'United Kingdom',
#         'formattedAddress': ['4 Strutton Ground (at Old Pye St)',
#          'London',
#          'Greater London',
#          'SW1P 2HR',
#          'United Kingdom']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b0c6aa1f964a520cd3c23e3-7'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '53c3c3ee498eb2376aa1a507',
#        'name': 'Keen',
#        'location': {'address': '3 Artillery Row',
#         'lat': 51.49728802999305,
#         'lng': -0.13576494535540826,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 51.49728802999305,
#           'lng': -0.13576494535540826}],
#         'distance': 95,
#         'postalCode': 'SW1H 0HZ',
#         'cc': 'GB',
#         'city': 'London',
#         'state': 'Greater London',
#         'country': 'United Kingdom',
#         'formattedAddress': ['3 Artillery Row',
#          'London',
#          'Greater London',
#          'SW1H 0HZ',
#          'United Kingdom']},
#        'categories': [{'id': '4bf58dd8d48988d1c5941735',
#          'name': 'Sandwich Place',
#          'pluralName': 'Sandwich Places',
#          'shortName': 'Sandwiches',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/deli_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-53c3c3ee498eb2376aa1a507-8'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bf40516e5eba593f3211f90',
#        'name': "St Ermin's Hotel",
#        'location': {'address': '2 Caxton Street',
#         'lat': 51.4991371,
#         'lng': -0.1344175,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 51.4991371,
#           'lng': -0.1344175}],
#         'distance': 276,
#         'postalCode': 'SW1H 0QW',
#         'cc': 'GB',
#         'city': 'City of London',
#         'state': 'Greater London',
#         'country': 'United Kingdom',
#         'formattedAddress': ['2 Caxton Street',
#          'City of London',
#          'Greater London',
#          'SW1H 0QW',
#          'United Kingdom']},
#        'categories': [{'id': '4bf58dd8d48988d1fa931735',
#          'name': 'Hotel',
#          'pluralName': 'Hotels',
#          'shortName': 'Hotel',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bf40516e5eba593f3211f90-9'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '52e2f3b011d27cfb545e0a40',
#        'name': "St. James' Court, A Taj Hotel",
#        'location': {'address': '54 Buckingham Gate',
#         'lat': 51.498647461551876,
#         'lng': -0.13703354074064655,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 51.498647461551876,
#           'lng': -0.13703354074064655}],
#         'distance': 147,
#         'postalCode': 'SW1E 6AF',
#         'cc': 'GB',
#         'city': 'London',
#         'state': 'Greater London',
#         'country': 'United Kingdom',
#         'formattedAddress': ['54 Buckingham Gate',
#          'London',
#          'Greater London',
#          'SW1E 6AF',
#          'United Kingdom']},
#        'categories': [{'id': '4bf58dd8d48988d1fa931735',
#          'name': 'Hotel',
#          'pluralName': 'Hotels',
#          'shortName': 'Hotel',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-52e2f3b011d27cfb545e0a40-10'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c84b19e74d7b60c2c2395d8',
#        'name': 'Strutton Ground Market',
#        'location': {'address': 'Strutton Ground',
#         'lat': 51.49678246763529,
#         'lng': -0.13371726225312403,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 51.49678246763529,
#           'lng': -0.13371726225312403}],
#         'distance': 245,
#         'postalCode': 'SW1',
#         'cc': 'GB',
#         'city': 'London',
#         'state': 'Greater London',
#         'country': 'United Kingdom',
#         'formattedAddress': ['Strutton Ground',
#          'London',
#          'Greater London',
#          ' SW1',
#          'United Kingdom']},
#        'categories': [{'id': '53e0feef498e5aac066fd8a9',
#          'name': 'Street Food Gathering',
#          'pluralName': 'Street Food Gatherings',
#          'shortName': 'Street Food Gathering',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/streetfood_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c84b19e74d7b60c2c2395d8-11'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4ca6168df47ea1438c145d21',
#        'name': 'Runners Need',
#        'location': {'address': '24 Palace Street, Victoria',
#         'lat': 51.4973815,
#         'lng': -0.1396394,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 51.4973815,
#           'lng': -0.1396394}],
#         'distance': 172,
#         'postalCode': 'SW1E 5JD',
#         'cc': 'GB',
#         'city': 'London',
#         'state': 'Greater London',
#         'country': 'United Kingdom',
#         'formattedAddress': ['24 Palace Street, Victoria',
#          'London',
#          'Greater London',
#          'SW1E 5JD',
#          'United Kingdom']},
#        'categories': [{'id': '4bf58dd8d48988d1f2941735',
#          'name': 'Sporting Goods Shop',
#          'pluralName': 'Sporting Goods Shops',
#          'shortName': 'Sporting Goods',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/sports_outdoors_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4ca6168df47ea1438c145d21-12'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '55eae15c498eadce48ff9470',
#        'name': 'Ibérica Victoria',
#        'location': {'address': '68 Victoria St',
#         'lat': 51.497293464802745,
#         'lng': -0.13812744994461612,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 51.497293464802745,
#           'lng': -0.13812744994461612}],
#         'distance': 67,
#         'postalCode': 'SW1E 6SQ',
#         'cc': 'GB',
#         'city': 'London',
#         'state': 'Greater London',
#         'country': 'United Kingdom',
#         'formattedAddress': ['68 Victoria St',
#          'London',
#          'Greater London',
#          'SW1E 6SQ',
#          'United Kingdom']},
#        'categories': [{'id': '4bf58dd8d48988d1db931735',
#          'name': 'Tapas Restaurant',
#          'pluralName': 'Tapas Restaurants',
#          'shortName': 'Tapas',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/tapas_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-55eae15c498eadce48ff9470-13'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4ac518e7f964a52060ab20e3',
#        'name': 'Victoria Palace Theatre',
#        'location': {'address': 'Victoria St',
#         'lat': 51.49684195968544,
#         'lng': -0.14220603100411708,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 51.49684195968544,
#           'lng': -0.14220603100411708}],
#         'distance': 354,
#         'postalCode': 'SW1E 5EA',
#         'cc': 'GB',
#         'city': 'London',
#         'state': 'Greater London',
#         'country': 'United Kingdom',
#         'formattedAddress': ['Victoria St',
#          'London',
#          'Greater London',
#          'SW1E 5EA',
#          'United Kingdom']},
#        'categories': [{'id': '4bf58dd8d48988d137941735',
#          'name': 'Theater',
#          'pluralName': 'Theaters',
#          'shortName': 'Theater',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/performingarts_theater_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4ac518e7f964a52060ab20e3-14'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '59f197412619ee4c46a2e0e3',
#        'name': 'JOE & THE JUICE',
#        'location': {'address': '70 Victoria Street',
#         'lat': 51.49714185844405,
#         'lng': -0.138509822998428,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 51.49714185844405,
#           'lng': -0.138509822998428}],
#         'distance': 96,
#         'postalCode': 'SW1E 6SQ',
#         'cc': 'GB',
#         'city': 'London',
#         'state': 'Greater London',
#         'country': 'United Kingdom',
#         'formattedAddress': ['70 Victoria Street',
#          'London',
#          'Greater London',
#          'SW1E 6SQ',
#          'United Kingdom']},
#        'categories': [{'id': '4bf58dd8d48988d112941735',
#          'name': 'Juice Bar',
#          'pluralName': 'Juice Bars',
#          'shortName': 'Juice Bar',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/juicebar_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-59f197412619ee4c46a2e0e3-15'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5665e6ac498e184c5e40521a',
#        'name': 'Gymbox',
#        'location': {'address': '123 Victoria St',
#         'lat': 51.49693429388782,
#         'lng': -0.13725722807217136,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 51.49693429388782,
#           'lng': -0.13725722807217136}],
#         'distance': 43,
#         'postalCode': 'SW1E 6DE',
#         'cc': 'GB',
#         'neighborhood': 'City of Westminster, London, Greater London',
#         'city': 'London',
#         'state': 'Greater London',
#         'country': 'United Kingdom',
#         'formattedAddress': ['123 Victoria St',
#          'London',
#          'Greater London',
#          'SW1E 6DE',
#          'United Kingdom']},
#        'categories': [{'id': '4bf58dd8d48988d176941735',
#          'name': 'Gym',
#          'pluralName': 'Gyms',
#          'shortName': 'Gym',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5665e6ac498e184c5e40521a-16'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4f02d63aa69d4546205f3086',
#        'name': 'Caxton Bar & Grill',
#        'location': {'address': '2 Caxton St',
#         'lat': 51.49874725493796,
#         'lng': -0.13420534253857905,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 51.49874725493796,
#           'lng': -0.13420534253857905}],
#         'distance': 258,
#         'postalCode': 'SW1H 0QW',
#         'cc': 'GB',
#         'city': 'London',
#         'state': 'Greater London',
#         'country': 'United Kingdom',
#         'formattedAddress': ['2 Caxton St',
#          'London',
#          'Greater London',
#          'SW1H 0QW',
#          'United Kingdom']},
#        'categories': [{'id': '4bf58dd8d48988d1d5941735',
#          'name': 'Hotel Bar',
#          'pluralName': 'Hotel Bars',
#          'shortName': 'Hotel Bar',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_bar_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4f02d63aa69d4546205f3086-17'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5412dfac498ee9ca9329e9f2',
#        'name': 'Conrad London St. James',
#        'location': {'address': '22-28 Broadway',
#         'lat': 51.49939556598363,
#         'lng': -0.13280432242097437,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 51.49939556598363,
#           'lng': -0.13280432242097437}],
#         'distance': 379,
#         'postalCode': 'SW1H 0BH',
#         'cc': 'GB',
#         'city': 'London',
#         'state': 'Greater London',
#         'country': 'United Kingdom',
#         'formattedAddress': ['22-28 Broadway',
#          'London',
#          'Greater London',
#          'SW1H 0BH',
#          'United Kingdom']},
#        'categories': [{'id': '4bf58dd8d48988d1fa931735',
#          'name': 'Hotel',
#          'pluralName': 'Hotels',
#          'shortName': 'Hotel',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5412dfac498ee9ca9329e9f2-18'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4adc8bf6f964a520182d21e3',
#        'name': 'Pret A Manger',
#        'location': {'address': '95 Victoria St',
#         'lat': 51.497486806013704,
#         'lng': -0.1356948460831648,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 51.497486806013704,
#           'lng': -0.1356948460831648}],
#         'distance': 102,
#         'postalCode': 'SW1H 0HW',
#         'cc': 'GB',
#         'neighborhood': 'Westminster, London, Greater London',
#         'city': 'London',
#         'state': 'Greater London',
#         'country': 'United Kingdom',
#         'formattedAddress': ['95 Victoria St',
#          'London',
#          'Greater London',
#          'SW1H 0HW',
#          'United Kingdom']},
#        'categories': [{'id': '4bf58dd8d48988d1c5941735',
#          'name': 'Sandwich Place',
#          'pluralName': 'Sandwich Places',
#          'shortName': 'Sandwiches',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/deli_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4adc8bf6f964a520182d21e3-19'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5ac61bc961e53b3252e34b86',
#        'name': 'Hamilton The Musical',
#        'location': {'lat': 51.496550606702066,
#         'lng': -0.14257782402355137,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 51.496550606702066,
#           'lng': -0.14257782402355137}],
#         'distance': 385,
#         'postalCode': 'SW1E 5LA',
#         'cc': 'GB',
#         'city': 'London',
#         'state': 'Greater London',
#         'country': 'United Kingdom',
#         'formattedAddress': ['London',
#          'Greater London',
#          'SW1E 5LA',
#          'United Kingdom']},
#        'categories': [{'id': '4bf58dd8d48988d137941735',
#          'name': 'Theater',
#          'pluralName': 'Theaters',
#          'shortName': 'Theater',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/performingarts_theater_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5ac61bc961e53b3252e34b86-20'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4cbc35099552b60c840de48b',
#        'name': 'Ichiriki Sushi House',
#        'location': {'address': '17b Strutton Ground',
#         'lat': 51.49734009769125,
#         'lng': -0.13384662202821634,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 51.49734009769125,
#           'lng': -0.13384662202821634}],
#         'distance': 228,
#         'postalCode': 'SW1P 2HY',
#         'cc': 'GB',
#         'city': 'London',
#         'state': 'Greater London',
#         'country': 'United Kingdom',
#         'formattedAddress': ['17b Strutton Ground',
#          'London',
#          'Greater London',
#          'SW1P 2HY',
#          'United Kingdom']},
#        'categories': [{'id': '4bf58dd8d48988d1d2941735',
#          'name': 'Sushi Restaurant',
#          'pluralName': 'Sushi Restaurants',
#          'shortName': 'Sushi',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/sushi_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4cbc35099552b60c840de48b-21'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4ac518e1f964a52042aa20e3',
#        'name': 'Bistro',
#        'location': {'address': '54 Buckingham Gate',
#         'lat': 51.49860297197118,
#         'lng': -0.13685535791739017,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 51.49860297197118,
#           'lng': -0.13685535791739017}],
#         'distance': 144,
#         'postalCode': 'SW1E 6AF',
#         'cc': 'GB',
#         'neighborhood': 'Westminster',
#         'city': 'London',
#         'state': 'Greater London',
#         'country': 'United Kingdom',
#         'formattedAddress': ['54 Buckingham Gate',
#          'London',
#          'Greater London',
#          'SW1E 6AF',
#          'United Kingdom']},
#        'categories': [{'id': '52e81612bcbc57f1066b79f1',
#          'name': 'Bistro',
#          'pluralName': 'Bistros',
#          'shortName': 'Bistro',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '61781688'}},
#       'referralId': 'e-0-4ac518e1f964a52042aa20e3-22'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c4ef758fa9d95219b64720a',
#        'name': 'itsu',
#        'location': {'address': '163 Victoria Street',
#         'lat': 51.496860817642194,
#         'lng': -0.1408380836925805,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 51.496860817642194,
#           'lng': -0.1408380836925805}],
#         'distance': 260,
#         'postalCode': 'SW1E 5NA',
#         'cc': 'GB',
#         'city': 'London',
#         'state': 'Greater London',
#         'country': 'United Kingdom',
#         'formattedAddress': ['163 Victoria Street',
#          'London',
#          'Greater London',
#          'SW1E 5NA',
#          'United Kingdom']},
#        'categories': [{'id': '4bf58dd8d48988d1d2941735',
#          'name': 'Sushi Restaurant',
#          'pluralName': 'Sushi Restaurants',
#          'shortName': 'Sushi',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/sushi_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c4ef758fa9d95219b64720a-23'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '52c9c91f498e32efeefe8556',
#        'name': 'Leon',
#        'location': {'address': 'Unit 3, 56 Victoria St',
#         'lat': 51.497495327145884,
#         'lng': -0.13646401454610851,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 51.497495327145884,
#           'lng': -0.13646401454610851}],
#         'distance': 51,
#         'postalCode': 'SW1E 6QW',
#         'cc': 'GB',
#         'city': 'London',
#         'state': 'Greater London',
#         'country': 'United Kingdom',
#         'formattedAddress': ['Unit 3, 56 Victoria St',
#          'London',
#          'Greater London',
#          'SW1E 6QW',
#          'United Kingdom']},
#        'categories': [{'id': '4bf58dd8d48988d16e941735',
#          'name': 'Fast Food Restaurant',
#          'pluralName': 'Fast Food Restaurants',
#          'shortName': 'Fast Food',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/fastfood_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-52c9c91f498e32efeefe8556-24'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bc8964015a7ef3b8e617bda',
#        'name': 'Buckingham Arms',
#        'location': {'address': '62 Petty France',
#         'crossStreet': 'near Buckingham Gate',
#         'lat': 51.499169,
#         'lng': -0.136858,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 51.499169,
#           'lng': -0.136858}],
#         'distance': 206,
#         'postalCode': 'SW1H 9EU',
#         'cc': 'GB',
#         'city': 'City of Westminster',
#         'state': 'Greater London',
#         'country': 'United Kingdom',
#         'formattedAddress': ['62 Petty France (near Buckingham Gate)',
#          'City of Westminster',
#          'Greater London',
#          'SW1H 9EU',
#          'United Kingdom']},
#        'categories': [{'id': '4bf58dd8d48988d11b941735',
#          'name': 'Pub',
#          'pluralName': 'Pubs',
#          'shortName': 'Pub',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bc8964015a7ef3b8e617bda-25'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5289db6411d2e4c3bdcfde2c',
#        'name': 'Café Nuovo',
#        'location': {'address': '12 Artillery Road',
#         'lat': 51.496609751725885,
#         'lng': -0.1355775302509602,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 51.496609751725885,
#           'lng': -0.1355775302509602}],
#         'distance': 134,
#         'postalCode': 'SW1P 1RZ',
#         'cc': 'GB',
#         'city': 'London',
#         'state': 'Greater London',
#         'country': 'United Kingdom',
#         'formattedAddress': ['12 Artillery Road',
#          'London',
#          'Greater London',
#          'SW1P 1RZ',
#          'United Kingdom']},
#        'categories': [{'id': '4bf58dd8d48988d143941735',
#          'name': 'Breakfast Spot',
#          'pluralName': 'Breakfast Spots',
#          'shortName': 'Breakfast',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/breakfast_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5289db6411d2e4c3bdcfde2c-26'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bfa7b105317a59348ad027f',
#        'name': 'Crussh',
#        'location': {'address': '3 Strutton Ground',
#         'lat': 51.49740513533402,
#         'lng': -0.13385757338423016,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 51.49740513533402,
#           'lng': -0.13385757338423016}],
#         'distance': 228,
#         'postalCode': 'SW1P 2HX',
#         'cc': 'GB',
#         'city': 'London',
#         'state': 'Greater London',
#         'country': 'United Kingdom',
#         'formattedAddress': ['3 Strutton Ground',
#          'London',
#          'Greater London',
#          'SW1P 2HX',
#          'United Kingdom']},
#        'categories': [{'id': '4bf58dd8d48988d112941735',
#          'name': 'Juice Bar',
#          'pluralName': 'Juice Bars',
#          'shortName': 'Juice Bar',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/juicebar_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bfa7b105317a59348ad027f-27'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '50080338e4b0b3c66239414f',
#        'name': 'The Other Palace',
#        'location': {'address': '12 Palace St',
#         'lat': 51.49896748137003,
#         'lng': -0.14224775454867583,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 51.49896748137003,
#           'lng': -0.14224775454867583}],
#         'distance': 398,
#         'postalCode': 'SW1E 5JA',
#         'cc': 'GB',
#         'city': 'London',
#         'state': 'Greater London',
#         'country': 'United Kingdom',
#         'formattedAddress': ['12 Palace St',
#          'London',
#          'Greater London',
#          'SW1E 5JA',
#          'United Kingdom']},
#        'categories': [{'id': '4bf58dd8d48988d137941735',
#          'name': 'Theater',
#          'pluralName': 'Theaters',
#          'shortName': 'Theater',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/performingarts_theater_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-50080338e4b0b3c66239414f-28'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b6044cbf964a520d5dc29e3',
#        'name': 'Caffe Grana',
#        'location': {'address': 'St James Park Tube Station',
#         'crossStreet': '55 Broadway',
#         'lat': 51.499477,
#         'lng': -0.133683,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 51.499477,
#           'lng': -0.133683}],
#         'distance': 339,
#         'postalCode': 'SW1H 0BB',
#         'cc': 'GB',
#         'city': 'London',
#         'state': 'Greater London',
#         'country': 'United Kingdom',
#         'formattedAddress': ['St James Park Tube Station (55 Broadway)',
#          'London',
#          'Greater London',
#          'SW1H 0BB',
#          'United Kingdom']},
#        'categories': [{'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'shortName': 'Café',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b6044cbf964a520d5dc29e3-29'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b5b1c6df964a520dae328e3',
#        'name': 'Apollo Victoria Theatre',
#        'location': {'address': '17 Wilton Rd',
#         'lat': 51.495621753996815,
#         'lng': -0.14268941294802595,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 51.495621753996815,
#           'lng': -0.14268941294802595}],
#         'distance': 428,
#         'postalCode': 'SW1V 1LG',
#         'cc': 'GB',
#         'city': 'Victoria',
#         'state': 'Greater London',
#         'country': 'United Kingdom',
#         'formattedAddress': ['17 Wilton Rd',
#          'Victoria',
#          'Greater London',
#          'SW1V 1LG',
#          'United Kingdom']},
#        'categories': [{'id': '4bf58dd8d48988d137941735',
#          'name': 'Theater',
#          'pluralName': 'Theaters',
#          'shortName': 'Theater',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/performingarts_theater_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b5b1c6df964a520dae328e3-30'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5565c24d498e2885d1b9a54e',
#        'name': 'Coffee Geek and Friends',
#        'location': {'address': 'Unit 22 Cardinal Place',
#         'crossStreet': '6 Cathedral Walk',
#         'lat': 51.497637766011685,
#         'lng': -0.14152261249881912,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 51.497637766011685,
#           'lng': -0.14152261249881912}],
#         'distance': 305,
#         'postalCode': 'SW1E 5JH',
#         'cc': 'GB',
#         'city': 'London',
#         'state': 'Greater London',
#         'country': 'United Kingdom',
#         'formattedAddress': ['Unit 22 Cardinal Place (6 Cathedral Walk)',
#          'London',
#          'Greater London',
#          'SW1E 5JH',
#          'United Kingdom']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5565c24d498e2885d1b9a54e-31'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5c0ec383da5e56002c288688',
#        'name': 'Flight Club Victoria',
#        'location': {'address': '6 Sir Simon Milton Sq',
#         'lat': 51.49744225891,
#         'lng': -0.14274716945000337,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 51.49744225891,
#           'lng': -0.14274716945000337}],
#         'distance': 388,
#         'postalCode': 'SW1E 5DJ',
#         'cc': 'GB',
#         'neighborhood': 'City of Westminster',
#         'city': 'Victoria',
#         'state': 'Greater London',
#         'country': 'United Kingdom',
#         'formattedAddress': ['6 Sir Simon Milton Sq',
#          'Victoria',
#          'Greater London',
#          'SW1E 5DJ',
#          'United Kingdom']},
#        'categories': [{'id': '4bf58dd8d48988d11e941735',
#          'name': 'Cocktail Bar',
#          'pluralName': 'Cocktail Bars',
#          'shortName': 'Cocktail',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/cocktails_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5c0ec383da5e56002c288688-32'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '58d56a65819079740580090b',
#        'name': 'Vagabond',
#        'location': {'address': '77, The Nova Building C',
#         'lat': 51.49754955939035,
#         'lng': -0.14373068106537867,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 51.49754955939035,
#           'lng': -0.14373068106537867}],
#         'distance': 456,
#         'postalCode': 'S W1E',
#         'cc': 'GB',
#         'city': 'London',
#         'state': 'Greater London',
#         'country': 'United Kingdom',
#         'formattedAddress': ['77, The Nova Building C',
#          'London',
#          'Greater London',
#          'S W1E',
#          'United Kingdom']},
#        'categories': [{'id': '4bf58dd8d48988d123941735',
#          'name': 'Wine Bar',
#          'pluralName': 'Wine Bars',
#          'shortName': 'Wine Bar',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/winery_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-58d56a65819079740580090b-33'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5dcf0c86f1c28a0008bf36d4',
#        'name': 'The Ivy',
#        'location': {'address': '66 Victoria St',
#         'lat': 51.497231,
#         'lng': -0.137959,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 51.497231,
#           'lng': -0.137959}],
#         'distance': 57,
#         'postalCode': 'SW1E 6AN',
#         'cc': 'GB',
#         'city': 'London',
#         'state': 'Greater London',
#         'country': 'United Kingdom',
#         'formattedAddress': ['66 Victoria St',
#          'London',
#          'Greater London',
#          'SW1E 6AN',
#          'United Kingdom']},
#        'categories': [{'id': '4bf58dd8d48988d1c4941735',
#          'name': 'Restaurant',
#          'pluralName': 'Restaurants',
#          'shortName': 'Restaurant',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5dcf0c86f1c28a0008bf36d4-34'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '56670ab9498e734aea57b1cb',
#        'name': 'The Nadler Victoria',
#        'location': {'address': '10 Palace Pl',
#         'lat': 51.49898781187463,
#         'lng': -0.1426808659097089,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 51.49898781187463,
#           'lng': -0.1426808659097089}],
#         'distance': 425,
#         'postalCode': 'SW1E 5BW',
#         'cc': 'GB',
#         'city': 'London',
#         'state': 'Greater London',
#         'country': 'United Kingdom',
#         'formattedAddress': ['10 Palace Pl',
#          'London',
#          'Greater London',
#          'SW1E 5BW',
#          'United Kingdom']},
#        'categories': [{'id': '4bf58dd8d48988d1fa931735',
#          'name': 'Hotel',
#          'pluralName': 'Hotels',
#          'shortName': 'Hotel',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-56670ab9498e734aea57b1cb-35'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bcf48880ffdce72bd58b2c0',
#        'name': 'Grange Wellington Hotel',
#        'location': {'address': '71-72 Vincent Sq',
#         'lat': 51.49468866755416,
#         'lng': -0.1361939483219042,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 51.49468866755416,
#           'lng': -0.1361939483219042}],
#         'distance': 300,
#         'postalCode': 'SW1P 2PA',
#         'cc': 'GB',
#         'city': 'London',
#         'state': 'Greater London',
#         'country': 'United Kingdom',
#         'formattedAddress': ['71-72 Vincent Sq',
#          'London',
#          'Greater London',
#          'SW1P 2PA',
#          'United Kingdom']},
#        'categories': [{'id': '4bf58dd8d48988d1fa931735',
#          'name': 'Hotel',
#          'pluralName': 'Hotels',
#          'shortName': 'Hotel',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bcf48880ffdce72bd58b2c0-36'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4ecd525a4690a03b59d7da07',
#        'name': 'Lime Orange',
#        'location': {'address': '312 Vauxhall Bridge Rd',
#         'lat': 51.49549645186136,
#         'lng': -0.1421165432571259,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 51.49549645186136,
#           'lng': -0.1421165432571259}],
#         'distance': 399,
#         'postalCode': 'SW1V 1AA',
#         'cc': 'GB',
#         'city': 'London',
#         'state': 'Greater London',
#         'country': 'United Kingdom',
#         'formattedAddress': ['312 Vauxhall Bridge Rd',
#          'London',
#          'Greater London',
#          'SW1V 1AA',
#          'United Kingdom']},
#        'categories': [{'id': '4bf58dd8d48988d113941735',
#          'name': 'Korean Restaurant',
#          'pluralName': 'Korean Restaurants',
#          'shortName': 'Korean',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/korean_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '557577218'}},
#       'referralId': 'e-0-4ecd525a4690a03b59d7da07-37'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b4b74d3f964a5206e9c26e3',
#        'name': 'The Speaker',
#        'location': {'address': '46 Great Peter St',
#         'crossStreet': "at Perkin's Rents",
#         'lat': 51.496876,
#         'lng': -0.132207,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 51.496876,
# ...
#        'name': 'Timmy Green',
#        'location': {'address': 'Buckingham Palace Rd',
#         'crossStreet': 'Bressenden St',
#         'lat': 51.49790250133684,
#         'lng': -0.14357279445482526,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 51.49790250133684,
#           'lng': -0.14357279445482526}],
#         'distance': 449,
#         'postalCode': 'SW1E 5DD',
#         'cc': 'GB',
#         'city': 'Victoria',
#         'state': 'Greater London',
#         'country': 'United Kingdom',
#         'formattedAddress': ['Buckingham Palace Rd (Bressenden St)',
#          'Victoria',
#          'Greater London',
#          'SW1E 5DD',
#          'United Kingdom']},
#        'categories': [{'id': '4bf58dd8d48988d169941735',
#          'name': 'Australian Restaurant',
#          'pluralName': 'Australian Restaurants',
#          'shortName': 'Australian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/australian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-58696c969dc8d02a32c545ef-62'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '59c6b9c591eaca5a7519d137',
#        'name': 'hub London Westminster Abbey',
#        'location': {'address': '21 Tothill St',
#         'lat': 51.49970123047254,
#         'lng': -0.13158712325585553,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 51.49970123047254,
#           'lng': -0.13158712325585553}],
#         'distance': 467,
#         'postalCode': 'SW1H 9LL',
#         'cc': 'GB',
#         'city': 'City of Westminster',
#         'state': 'Greater London',
#         'country': 'United Kingdom',
#         'formattedAddress': ['21 Tothill St',
#          'City of Westminster',
#          'Greater London',
#          'SW1H 9LL',
#          'United Kingdom']},
#        'categories': [{'id': '4bf58dd8d48988d1fa931735',
#          'name': 'Hotel',
#          'pluralName': 'Hotels',
#          'shortName': 'Hotel',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-59c6b9c591eaca5a7519d137-63'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4e58fe2fb0fbdca309f6b710',
#        'name': "St James' Park Playground",
#        'location': {'address': 'St James Park',
#         'lat': 51.5011191867234,
#         'lng': -0.13831530863951114,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 51.5011191867234,
#           'lng': -0.13831530863951114}],
#         'distance': 430,
#         'postalCode': 'SW1A 2BJ',
#         'cc': 'GB',
#         'city': 'London',
#         'state': 'Greater London',
#         'country': 'United Kingdom',
#         'formattedAddress': ['St James Park',
#          'London',
#          'Greater London',
#          'SW1A 2BJ',
#          'United Kingdom']},
#        'categories': [{'id': '4bf58dd8d48988d1e7941735',
#          'name': 'Playground',
#          'pluralName': 'Playgrounds',
#          'shortName': 'Playground',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/playground_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4e58fe2fb0fbdca309f6b710-64'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5914106918d43b1f07c8adfc',
#        'name': 'Shot Espresso',
#        'location': {'address': '10 Bressenden Place',
#         'lat': 51.49806439501044,
#         'lng': -0.14239320047524007,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 51.49806439501044,
#           'lng': -0.14239320047524007}],
#         'distance': 372,
#         'postalCode': 'S W1E',
#         'cc': 'GB',
#         'city': 'London',
#         'state': 'Greater London',
#         'country': 'United Kingdom',
#         'formattedAddress': ['10 Bressenden Place',
#          'London',
#          'Greater London',
#          'S W1E',
#          'United Kingdom']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5914106918d43b1f07c8adfc-65'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4ac518b6f964a520d7a020e3',
#        'name': 'The Rubens at The Palace',
#        'location': {'address': '39 Buckingham Palace Rd',
#         'lat': 51.49837679874355,
#         'lng': -0.1436007395327031,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 51.49837679874355,
#           'lng': -0.1436007395327031}],
#         'distance': 462,
#         'postalCode': 'SW1W 0PS',
#         'cc': 'GB',
#         'city': 'London',
#         'state': 'Greater London',
#         'country': 'United Kingdom',
#         'formattedAddress': ['39 Buckingham Palace Rd',
#          'London',
#          'Greater London',
#          'SW1W 0PS',
#          'United Kingdom']},
#        'categories': [{'id': '4bf58dd8d48988d1fa931735',
#          'name': 'Hotel',
#          'pluralName': 'Hotels',
#          'shortName': 'Hotel',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '574695328'}},
#       'referralId': 'e-0-4ac518b6f964a520d7a020e3-66'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '51b07dec498e322eca539d44',
#        'name': 'Mr. Cad',
#        'location': {'address': '12 Upper Tachbrook St.',
#         'lat': 51.49337657545596,
#         'lng': -0.13950050586205887,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 51.49337657545596,
#           'lng': -0.13950050586205887}],
#         'distance': 468,
#         'postalCode': 'SW1V 1SH',
#         'cc': 'GB',
#         'city': 'London',
#         'state': 'Greater London',
#         'country': 'United Kingdom',
#         'formattedAddress': ['12 Upper Tachbrook St.',
#          'London',
#          'Greater London',
#          'SW1V 1SH',
#          'United Kingdom']},
#        'categories': [{'id': '4eb1bdf03b7b55596b4a7491',
#          'name': 'Camera Store',
#          'pluralName': 'Camera Stores',
#          'shortName': 'Camera Store',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/camerastore_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-51b07dec498e322eca539d44-67'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4dcefc35183899ddfae17a2e',
#        'name': 'Cavalry Bar at The Rubens',
#        'location': {'lat': 51.49823589163048,
#         'lng': -0.14346575772272274,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 51.49823589163048,
#           'lng': -0.14346575772272274}],
#         'distance': 449,
#         'cc': 'GB',
#         'city': 'London',
#         'state': 'Greater London',
#         'country': 'United Kingdom',
#         'formattedAddress': ['London', 'Greater London', 'United Kingdom']},
#        'categories': [{'id': '4bf58dd8d48988d11b941735',
#          'name': 'Pub',
#          'pluralName': 'Pubs',
#          'shortName': 'Pub',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4dcefc35183899ddfae17a2e-68'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bc33143dce4eee1b17b719d',
#        'name': '41 Hotel',
#        'location': {'address': '41 Buckingham Palace Rd.',
#         'lat': 51.4981731434548,
#         'lng': -0.14310532613546195,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 51.4981731434548,
#           'lng': -0.14310532613546195}],
#         'distance': 423,
#         'postalCode': 'SW1W 0PS',
#         'cc': 'GB',
#         'city': 'London',
#         'state': 'Greater London',
#         'country': 'United Kingdom',
#         'formattedAddress': ['41 Buckingham Palace Rd.',
#          'London',
#          'Greater London',
#          'SW1W 0PS',
#          'United Kingdom']},
#        'categories': [{'id': '4bf58dd8d48988d1fa931735',
#          'name': 'Hotel',
#          'pluralName': 'Hotels',
#          'shortName': 'Hotel',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '578698866'}},
#       'referralId': 'e-0-4bc33143dce4eee1b17b719d-69'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '59e502c31f74406800228913',
#        'name': 'The Curry Room',
#        'location': {'address': '39 Buckingham Palace Road',
#         'lat': 51.4982903,
#         'lng': -0.1435427,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 51.4982903,
#           'lng': -0.1435427}],
#         'distance': 456,
#         'postalCode': 'SW1W 0PS',
#         'cc': 'GB',
#         'city': 'London',
#         'state': 'Greater London',
#         'country': 'United Kingdom',
#         'formattedAddress': ['39 Buckingham Palace Road',
#          'London',
#          'Greater London',
#          'SW1W 0PS',
#          'United Kingdom']},
#        'categories': [{'id': '4bf58dd8d48988d10f941735',
#          'name': 'Indian Restaurant',
#          'pluralName': 'Indian Restaurants',
#          'shortName': 'Indian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '578463014'}},
#       'referralId': 'e-0-59e502c31f74406800228913-70'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '589cb7ba5a58692759902ef3',
#        'name': 'Hai Cenato',
#        'location': {'address': '2 Sir Simon Milton Square',
#         'lat': 51.497138445568766,
#         'lng': -0.14382853094597967,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 51.497138445568766,
#           'lng': -0.14382853094597967}],
#         'distance': 463,
#         'postalCode': 'SW1E 5DJ',
#         'cc': 'GB',
#         'city': 'Victoria',
#         'state': 'Greater London',
#         'country': 'United Kingdom',
#         'formattedAddress': ['2 Sir Simon Milton Square',
#          'Victoria',
#          'Greater London',
#          'SW1E 5DJ',
#          'United Kingdom']},
#        'categories': [{'id': '4bf58dd8d48988d110941735',
#          'name': 'Italian Restaurant',
#          'pluralName': 'Italian Restaurants',
#          'shortName': 'Italian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-589cb7ba5a58692759902ef3-71'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b61dbc2f964a52082272ae3',
#        'name': 'The Jugged Hare',
#        'location': {'address': '172 Vauxhall Bridge Road, Victoria',
#         'crossStreet': 'at Warwick Way',
#         'lat': 51.4930434,
#         'lng': -0.1382397,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 51.4930434,
#           'lng': -0.1382397}],
#         'distance': 482,
#         'postalCode': 'SW1V 1DX',
#         'cc': 'GB',
#         'city': 'Pimlico',
#         'state': 'Greater London',
#         'country': 'United Kingdom',
#         'formattedAddress': ['172 Vauxhall Bridge Road, Victoria (at Warwick Way)',
#          'Pimlico',
#          'Greater London',
#          'SW1V 1DX',
#          'United Kingdom']},
#        'categories': [{'id': '4bf58dd8d48988d11b941735',
#          'name': 'Pub',
#          'pluralName': 'Pubs',
#          'shortName': 'Pub',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b61dbc2f964a52082272ae3-72'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4ac518f6f964a52082af20e3',
#        'name': 'Queen Mother Sports Centre',
#        'location': {'address': '223 Vauxhall Bridge Rd',
#         'lat': 51.49385584078819,
#         'lng': -0.1403239233097453,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 51.49385584078819,
#           'lng': -0.1403239233097453}],
#         'distance': 444,
#         'postalCode': 'SW1V 1EL',
#         'cc': 'GB',
#         'city': 'London',
#         'state': 'Greater London',
#         'country': 'United Kingdom',
#         'formattedAddress': ['223 Vauxhall Bridge Rd',
#          'London',
#          'Greater London',
#          'SW1V 1EL',
#          'United Kingdom']},
#        'categories': [{'id': '4bf58dd8d48988d175941735',
#          'name': 'Gym / Fitness Center',
#          'pluralName': 'Gyms or Fitness Centers',
#          'shortName': 'Gym / Fitness',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4ac518f6f964a52082af20e3-73'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c7e3968d65437047c86c2a2',
#        'name': 'Subway',
#        'location': {'address': '10 Upper Tachbrook St',
#         'crossStreet': 'At Vauxhall Bridge Rd',
#         'lat': 51.49331503098221,
#         'lng': -0.13948277387470773,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 51.49331503098221,
#           'lng': -0.13948277387470773}],
#         'distance': 474,
#         'postalCode': 'SW1V 1SH',
#         'cc': 'GB',
#         'city': 'London',
#         'state': 'Greater London',
#         'country': 'United Kingdom',
#         'formattedAddress': ['10 Upper Tachbrook St (At Vauxhall Bridge Rd)',
#          'London',
#          'Greater London',
#          'SW1V 1SH',
#          'United Kingdom']},
#        'categories': [{'id': '4bf58dd8d48988d1c5941735',
#          'name': 'Sandwich Place',
#          'pluralName': 'Sandwich Places',
#          'shortName': 'Sandwiches',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/deli_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c7e3968d65437047c86c2a2-74'}]}]}}

# %% [markdown]
# Creating a function that extracts the category of the venue

# %%
def get_details(venue_id):
        
    #url to fetch data from foursquare api
    url = 'https://api.foursquare.com/v2/venues/{}?&client_id={}&client_secret={}&v={}'.format(
            venue_id,
            cred['CLIENT_ID'], 
            cred['CLIENT_SECRET'], 
            VERSION)
    #print(url)
    # get all the data
    results = requests.get(url).json()
    return results

# %%
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

venues = results['response']['groups'][0]['items']
    
nearby_venues = json_normalize(venues) # flatten JSON

# filter columns
filtered_columns = ['venue.name', 'venue.id', 'venue.categories', 'venue.location.lat', 'venue.location.lng']
nearby_venues =nearby_venues.loc[:, filtered_columns]

# filter the category for each row
nearby_venues['venue.categories'] = nearby_venues.apply(get_category_type, axis=1)

# clean columns
nearby_venues.columns = [col.split(".")[-1] for col in nearby_venues.columns]

nearby_venues
# Out:
# <ipython-input-15-0d966b2f5908>:14: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   nearby_venues = json_normalize(venues) # flatten JSON
#                                            name                        id  \
# 0                               Curzon Victoria  53645bf211d2576d6ff59feb
# 1                                  Run & Become  4b648050f964a52095b82ae3
# 2                                   Iris & June  534295ec498e271e54f5f569
# 3   Taj  51 Buckingham Gate Suites & Residences  4f64ea20e4b0c7552d443a6c
# 4                               Chez Antoinette  5c67f97335d3fc002c79193b
# ..                                          ...                       ...
# 70                               The Curry Room  59e502c31f74406800228913
# 71                                   Hai Cenato  589cb7ba5a58692759902ef3
# 72                              The Jugged Hare  4b61dbc2f964a52082272ae3
# 73                   Queen Mother Sports Centre  4ac518f6f964a52082af20e3
# 74                                       Subway  4c7e3968d65437047c86c2a2
#
#               categories        lat       lng
# 0          Movie Theater  51.497473 -0.136744
# 1    Sporting Goods Shop  51.498128 -0.135426
# 2            Coffee Shop  51.496791 -0.136011
# 3                  Hotel  51.498598 -0.137404
# 4      French Restaurant  51.497964 -0.135455
# ..                   ...        ...       ...
# 70     Indian Restaurant  51.498290 -0.143543
# 71    Italian Restaurant  51.497138 -0.143829
# 72                   Pub  51.493043 -0.138240
# 73  Gym / Fitness Center  51.493856 -0.140324
# 74        Sandwich Place  51.493315 -0.139483
#
# [75 rows x 5 columns]

# %% [markdown]
# Let's see what are the different venues in our dataframe

# %%
nearby_venues['categories'].value_counts()
# Out:
# Coffee Shop                   9
# Hotel                         9
# Sandwich Place                7
# Pub                           4
# Theater                       4
# Sushi Restaurant              3
# Gym / Fitness Center          3
# Italian Restaurant            3
# Indian Restaurant             2
# Hotel Bar                     2
# Juice Bar                     2
# Sporting Goods Shop           2
# Breakfast Spot                1
# Tea Room                      1
# Pedestrian Plaza              1
# Australian Restaurant         1
# Modern European Restaurant    1
# Chocolate Shop                1
# Art Gallery                   1
# Café                          1
# French Restaurant             1
# Tapas Restaurant              1
# Camera Store                  1
# Supermarket                   1
# Beer Bar                      1
# Fast Food Restaurant          1
# Playground                    1
# Cocktail Bar                  1
# Scandinavian Restaurant       1
# Historic Site                 1
# Street Food Gathering         1
# Bistro                        1
# Korean Restaurant             1
# Movie Theater                 1
# Wine Bar                      1
# Gym                           1
# Restaurant                    1
# Name: categories, dtype: int64

# %%
# for id in nearby_venues['id'].tolist():
#     print(get_details(id))
